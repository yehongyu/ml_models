# %%
print("hello world")
# Out:
# hello world

# %%
print(1+2)
# Out:
# 3

# %%
import collections
collections.namedtuple?

# %%
aaa = set()
aaa.add
import tensorflow as tf
hello = tf.constant('Hello, TensorFlow!')
sess = tf.Session()
print(sess.run(hello))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-a624f6db6ec7> in <module>
#       3 import tensorflow as tf
#       4 hello = tf.constant('Hello, TensorFlow!')
# ----> 5 sess = tf.Session()
#       6 print(sess.run(hello))
#
# AttributeError: module 'tensorflow' has no attribute 'Session'

# %%
import tensorflow as tf
features = {}
features['f0'] = tf.placeholder(tf.float32, shape=[None], name='f0')
features['f1'] = tf.placeholder(tf.float32, shape=[None], name='f1')
features['f2'] = tf.placeholder(tf.float32, shape=[None], name='f2')
reveiver = tf.estimator.export.ServingInputReceiver(features, features)
type(receiver)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-27d58a67deb1> in <module>
#       1 import tensorflow as tf
#       2 features = {}
# ----> 3 features['f0'] = tf.placeholder(tf.float32, shape=[None], name='f0')
#       4 features['f1'] = tf.placeholder(tf.float32, shape=[None], name='f1')
#       5 features['f2'] = tf.placeholder(tf.float32, shape=[None], name='f2')
#
# AttributeError: module 'tensorflow' has no attribute 'placeholder'

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 2*np.pi, 300)
y = np.sin(x**2)
plt.plot(x, y)
plt.title("A little chirp")
fig = plt.gcf()  # let's keep the figure object around for later...
